
#  07-04-2024 22:52:10
#  07-04-2024 22:52:11                8691.0               16761.0
#  07-04-2024 22:52:12                8701.0               16750.0
#  07-04-2024 22:52:13                8707.0               16780.0
#  07-04-2024 22:52:14                8753.0               16913.0
#  07-04-2024 22:52:15                8773.0               16982.0
# ...                                    ...                   ...
#  07-04-2024 23:00:14                8558.0               16265.0
#  07-04-2024 23:00:15                8540.0               16227.0
#  07-04-2024 23:00:16                8542.0               16229.0
#  07-04-2024 23:00:17                8545.0               16228.0
#  07-04-2024 23:00:18                8536.0               16221.0
#
#                       Framerate             Frametime             \
#  07-04-2024 22:52:10
#  07-04-2024 22:52:11                  59.3                19.439
#  07-04-2024 22:52:12                  59.6                19.795
#  07-04-2024 22:52:13                  59.1                22.921
#  07-04-2024 22:52:14                  55.9                38.013
#  07-04-2024 22:52:15                  49.2               103.648
# ...                                    ...                   ...
#  07-04-2024 23:00:14                  59.2                18.779
#  07-04-2024 23:00:15                  59.2                18.713
#  07-04-2024 23:00:16                  59.4                20.450
#  07-04-2024 23:00:17                  59.4                19.838
#  07-04-2024 23:00:18                  59.3                18.444
#
#                       Framerate Min         Framerate Avg         \
#  07-04-2024 22:52:10
#  07-04-2024 22:52:11  N/A                   N/A
#  07-04-2024 22:52:12  N/A                   N/A
#  07-04-2024 22:52:13  N/A                   N/A
#  07-04-2024 22:52:14  N/A                   N/A
#  07-04-2024 22:52:15  N/A                   N/A
# ...                                    ...                   ...
#  07-04-2024 23:00:14  N/A                   N/A
#  07-04-2024 23:00:15  N/A                   N/A
#  07-04-2024 23:00:16  N/A                   N/A
#  07-04-2024 23:00:17  N/A                   N/A
#  07-04-2024 23:00:18  N/A                   N/A
#
#                       Framerate Max
#  07-04-2024 22:52:10
#  07-04-2024 22:52:11  N/A
#  07-04-2024 22:52:12  N/A
#  07-04-2024 22:52:13  N/A
#  07-04-2024 22:52:14  N/A
#  07-04-2024 22:52:15  N/A
# ...                                    ...
#  07-04-2024 23:00:14  N/A
#  07-04-2024 23:00:15  N/A
#  07-04-2024 23:00:16  N/A
#  07-04-2024 23:00:17  N/A
#  07-04-2024 23:00:18  N/A
#
# [423 rows x 62 columns]

# %%
data2=pd.read_csv('/Users/yaohaorong/Desktop/log/云星铁-跑图.csv')
data2.set_index(data2.columns[1], inplace=True) 
df2 = pd.DataFrame(data2, columns=data2.columns, index=data2.index)
# 获取第二个 DataFrame 的时间序列并调整起点为0秒
df2_time = pd.to_datetime(df2.index)  # 将索引转换为时间序列
df2_time_adjusted = (df2_time - df2_time[0]).total_seconds()  # 以秒为单位调整时间起点为0
df2
# Out:
#                       02   GPU temperature       GPU usage             \
#  07-04-2024 23:28:09
#  07-04-2024 23:28:09  80                   47.0                   8.0
#  07-04-2024 23:28:10  80                   47.0                   8.0
#  07-04-2024 23:28:11  80                   47.0                  20.0
#  07-04-2024 23:28:12  80                   47.0                  11.0
#  07-04-2024 23:28:13  80                   47.0                  13.0
#        'CPU7 temperature    ', 'CPU8 temperature    ', 'CPU9 temperature    ',
#        'CPU10 temperature   ', 'CPU11 temperature   ', 'CPU12 temperature   ',
#        'CPU temperature     ', 'CPU1 usage          ', 'CPU2 usage          ',
#        'CPU3 usage          ', 'CPU4 usage          ', 'CPU5 usage          ',
#        'CPU6 usage          ', 'CPU7 usage          ', 'CPU8 usage          ',
#        'CPU9 usage          ', 'CPU10 usage         ', 'CPU11 usage         ',
#        'CPU12 usage         ', 'CPU usage           ', 'CPU1 clock          ',
#        'CPU2 clock          ', 'CPU3 clock          ', 'CPU4 clock          ',
#        'CPU5 clock          ', 'CPU6 clock          ', 'CPU7 clock          ',
#        'CPU8 clock          ', 'CPU9 clock          ', 'CPU10 clock         ',
#        'CPU11 clock         ', 'CPU12 clock         ', 'CPU clock           ',
#        'CPU power           ', 'RAM usage           ', 'Commit charge       ',
#        'Framerate           ', 'Frametime           ', 'Framerate Min       ',
#        'Framerate Avg       ', 'Framerate Max       '],
#       dtype='object')
# Index(['02', ' GPU temperature     ', 'GPU usage           ',
#        'FB usage            ', 'VID usage           ', 'BUS usage           ',
#        'Memory usage        ', 'Core clock          ', 'Memory clock        ',
#        'Power percent       ', 'Power               ', 'Temp limit          ',
#        'Power limit         ', 'Voltage limit       ', 'No load limit       ',
#        'CPU1 temperature    ', 'CPU2 temperature    ', 'CPU3 temperature    ',
#        'CPU4 temperature    ', 'CPU5 temperature    ', 'CPU6 temperature    ',
#        'CPU7 temperature    ', 'CPU8 temperature    ', 'CPU9 temperature    ',
#        'CPU10 temperature   ', 'CPU11 temperature   ', 'CPU12 temperature   ',
#        'CPU temperature     ', 'CPU1 usage          ', 'CPU2 usage          ',
#        'CPU3 usage          ', 'CPU4 usage          ', 'CPU5 usage          ',
#        'CPU6 usage          ', 'CPU7 usage          ', 'CPU8 usage          ',
#        'CPU9 usage          ', 'CPU10 usage         ', 'CPU11 usage         ',
#        'CPU12 usage         ', 'CPU usage           ', 'CPU1 clock          ',
#        'CPU2 clock          ', 'CPU3 clock          ', 'CPU4 clock          ',
#        'CPU5 clock          ', 'CPU6 clock          ', 'CPU7 clock          ',
#        'CPU8 clock          ', 'CPU9 clock          ', 'CPU10 clock         ',
#        'CPU11 clock         ', 'CPU12 clock         ', 'CPU clock           ',
#        'CPU power           ', 'RAM usage           ', 'Commit charge       ',
#        'Framerate           ', 'Frametime           ', 'Framerate Min       ',
#        'Framerate Avg       ', 'Framerate Max       '],
#       dtype='object')

# %%
# df1[' GPU temperature     '] = df1[' GPU temperature     '].str.strip().astype(float)
# df2[' GPU temperature     '] = df2[' GPU temperature     '].str.strip().astype(float)
# df1
# df1[' GPU temperature     '].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df1[' GPU temperature     '] = df1[' GPU temperature     '].str.strip().astype(float)
#       2 df2[' GPU temperature     '] = df2[' GPU temperature     '].str.strip().astype(float)
#       3 df1
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))

# 绘制第一个 DataFrame 的 "GPU temperature"
plt.plot(df1_time_adjusted, df1[' GPU temperature     '], label='Local Running GPU Temperature')

# 绘制第二个 DataFrame 的 "GPU1 temperature"
plt.plot(df2_time_adjusted, df2[' GPU temperature     '], label='Cloud Running GPU Temperature')

# 设置图形标题和标签
plt.title('GPU Temperature Over Time')
plt.xlabel('Time (seconds since start)')
plt.ylabel('Temperature')
plt.legend()

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))

# 绘制第一个 DataFrame 的 "GPU usage"
plt.plot(df1_time_adjusted, df1['GPU usage           '], label='Local Running GPU Usage')

# 绘制第二个 DataFrame 的 "GPU usage"
plt.plot(df2_time_adjusted, df2['GPU usage           '], label='Cloud Running GPU Usage')

# 设置图形标题和标签
plt.title('GPU Usage Over Time')
plt.xlabel('Time (seconds since start)')
plt.ylabel('usage')
plt.legend()

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))

# 绘制第一个 DataFrame 的 "GPU memeory usage"
plt.plot(df1_time_adjusted, df1['Memory usage        '], label='Local Running GPU Memeory Usage')

# 绘制第二个 DataFrame 的 "GPU1 memoery usage"
plt.plot(df2_time_adjusted, df2['Memory usage        '], label='Cloud Running GPU Memory Usage')

# 设置图形标题和标签
plt.title('GPU Memory Usage Over Time')
plt.xlabel('Time (seconds since start)')
plt.ylabel('memory usage')
plt.legend()

# %%
df1['Framerate           ']
# Out:
#  07-04-2024 22:52:10
#  07-04-2024 22:52:11    59.3
#  07-04-2024 22:52:12    59.6
#  07-04-2024 22:52:13    59.1
#  07-04-2024 22:52:14    55.9
#  07-04-2024 22:52:15    49.2
#                         ...
#  07-04-2024 23:00:14    59.2
#  07-04-2024 23:00:15    59.2
#  07-04-2024 23:00:16    59.4
#  07-04-2024 23:00:17    59.4
#  07-04-2024 23:00:18    59.3
# Name: Framerate           , Length: 423, dtype: float64

# %%
df2['Framerate           ']
# Out:
#  07-04-2024 23:28:09
#  07-04-2024 23:28:09    N/A
#  07-04-2024 23:28:10    N/A
#  07-04-2024 23:28:11    N/A
#  07-04-2024 23:28:12    N/A
#  07-04-2024 23:28:13    N/A
#                                 ...
#  07-04-2024 23:30:35    N/A
#  07-04-2024 23:30:36    N/A
#  07-04-2024 23:30:37    N/A
#  07-04-2024 23:30:38    N/A
#  07-04-2024 23:30:39    N/A
# Name: Framerate           , Length: 151, dtype: object

# %%
unique_values = df1['Framerate           '].unique()
print(unique_values)
# Out:
# ['N/A                 ' '60.000              ' '59.700              '
#  '22.300              ' '59.900              ' '59.800              '
#  '57.500              ' '16.800              ' '109.800             '
#  '71.500              ' '71.000              ' '70.800              '
#  '70.600              ' '68.800              ' '71.100              '
#  '47.600              ' '56.800              ' '56.400              '
#  '53.500              ' '54.000              ' '52.200              '
#  '53.000              ' '53.700              ' '50.500              '
#  '51.900              ' '51.800              ' '51.600              '
#  '52.700              ' '51.400              ' '50.000              '
#  '51.200              ' '49.300              ' '52.800              '
#  '50.400              ' '56.600              ' '53.600              '
#  '56.300              ' '61.800              ' '61.200              '
#  '53.300              ' '52.100              ' '55.300              '
#  '52.400              ' '50.900              ' '49.700              '
#  '49.600              ' '54.400              ' '62.600              '
#  '66.000              ' '63.600              ' '53.400              '
#  '60.700              ' '59.300              ' '62.400              '
#  '61.500              ' '59.400              ' '62.100              '
#  '61.700              ' '62.900              ' '51.500              '
#  '55.100              ' '50.700              ' '52.000              '
#  '50.300              ' '50.100              ' '49.500              '
#  '48.800              ' '47.800              ' '49.900              '
#  '49.100              ' '97.600              ' '84.600              '
#  '42.000              ' '125.100             ' '116.800             '
#  '97.800              ' '119.600             ' '130.700             '
#  '116.300             ' '125.700             ' '140.400             '
#  '142.400             ' '136.600             ' '140.300             '
#  '144.200             ' '73.500              ' '46.600              ']

# %%
df1['Framerate           '] = df1['Framerate           '].replace('N/A                 ', '0')
df2['Framerate           '] = df2['Framerate           '].replace('N/A                 ', '0')
df1['Framerate           '] = df1['Framerate           '].str.strip().astype(float)
df2['Framerate           '] = df2['Framerate           '].str.strip().astype(float)
df1['Framerate           ']
df2['Framerate           ']
# Out:
#  Time
#  25-04-2024 10:18:08    0.7
#  25-04-2024 10:18:08    0.7
#  25-04-2024 10:18:09    0.0
#  25-04-2024 10:18:10    0.0
#  25-04-2024 10:18:11    0.0
#                        ...
#  25-04-2024 10:36:48    0.2
#  25-04-2024 10:36:49    0.0
#  25-04-2024 10:36:50    0.0
#  25-04-2024 10:36:51    0.0
#  25-04-2024 10:36:52    0.0
# Name: Framerate           , Length: 1126, dtype: float64

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))

# 绘制第一个 DataFrame 的 "Framerate"
plt.plot(df1_time_adjusted, df1['Framerate           '], label='Local Framerate')

# 绘制第二个 DataFrame 的 "Framerate"
plt.plot(df2_time_adjusted, df2['Framerate           '], label='Cloud Framerate')

# 设置图形标题和标签
plt.title('Framerate')
plt.xlabel('Time (seconds since start)')
plt.ylabel('Framerate')
plt.legend()

# %%
# 绘制折线图
plt.figure(figsize=(10, 6))

# 绘制第一个 DataFrame 的 "RAM usage"
plt.plot(df1_time_adjusted, df1['RAM usage           '], label='Local Running RAM usage')

# 绘制第二个 DataFrame 的 "RAM usage"
plt.plot(df2_time_adjusted, df2['RAM usage           '], label='Cloud Running RAM usage')

# 设置图形标题和标签
plt.title('RAM usage')
plt.xlabel('Time (seconds since start)')
plt.ylabel('RAM usage')
plt.legend()

# %%
df1.columns
# Out:
# Index(['02', ' GPU temperature     ', 'GPU usage           ',
#        'FB usage            ', 'VID usage           ', 'BUS usage           ',
#        'Memory usage        ', 'Core clock          ', 'Memory clock        ',
#        'Power percent       ', 'Power               ', 'Temp limit          ',
#        'Power limit         ', 'Voltage limit       ', 'No load limit       ',
#        'CPU1 temperature    ', 'CPU2 temperature    ', 'CPU3 temperature    ',
#        'CPU4 temperature    ', 'CPU5 temperature    ', 'CPU6 temperature    ',
#        'CPU7 temperature    ', 'CPU8 temperature    ', 'CPU9 temperature    ',
#        'CPU10 temperature   ', 'CPU11 temperature   ', 'CPU12 temperature   ',
#        'CPU temperature     ', 'CPU1 usage          ', 'CPU2 usage          ',
#        'CPU3 usage          ', 'CPU4 usage          ', 'CPU5 usage          ',
#        'CPU6 usage          ', 'CPU7 usage          ', 'CPU8 usage          ',
#        'CPU9 usage          ', 'CPU10 usage         ', 'CPU11 usage         ',
#        'CPU12 usage         ', 'CPU usage           ', 'CPU1 clock          ',
#        'CPU2 clock          ', 'CPU3 clock          ', 'CPU4 clock          ',
#        'CPU5 clock          ', 'CPU6 clock          ', 'CPU7 clock          ',
#        'CPU8 clock          ', 'CPU9 clock          ', 'CPU10 clock         ',
#        'CPU11 clock         ', 'CPU12 clock         ', 'CPU clock           ',
#        'CPU power           ', 'RAM usage           ', 'Commit charge       ',
#        'Framerate           ', 'Frametime           ', 'Framerate Min       ',
#        'Framerate Avg       ', 'Framerate Max       '],
#       dtype='object')

# %%
# 生成 'CPU1 temperature' 到 'CPU9 temperature' 的列名列表
cpu_temperature_1 = [f'CPU{i} temperature    ' for i in range(1, 10)]

# 生成 'CPU10 temperature' 到 'CPU12 temperature' 的列名列表
cpu_temperature_2 = [f'CPU{i} temperature   ' for i in range(10, 13)]

# 合并两个列表
cpu_temperature = cpu_temperature_1 + cpu_temperature_2

# 创建一个 4x3 的图像
fig, axs = plt.subplots(4, 3, figsize=(18, 24))
axs = axs.ravel()  # 将二维数组展平，方便遍历

# 遍历每个 CPU 温度列，在对应的子图中绘制折线图
for i, cpu_col in enumerate(cpu_temperature):
    row = i // 2  # 计算子图所在的行索引
    col = i % 2   # 计算子图所在的列索引
    
    # 绘制 df1 中对应 CPU 温度的折线图
    axs[i].plot(df1_time_adjusted, df1[cpu_col], label='Local Running Data', color='blue')
    
    # 绘制 df2 中对应 CPU 温度的折线图
    axs[i].plot(df2_time_adjusted, df2[cpu_col], label='Cloud Running Data', color='orange')
    
    # 设置子图标题和标签
    axs[i].set_title(cpu_col.strip())  # 去除列名中的额外空格并作为子图标题
    axs[i].set_xlabel('Time (seconds since start)')
    axs[i].set_ylabel('Temperature')
    axs[i].legend()  # 显示图例

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %%
# 生成 'CPU1 usage' 到 'CPU9 usage' 的列名列表
cpu_usage_1 = [f'CPU{i} usage          ' for i in range(1, 10)]

# 生成 'CPU10 temperature' 到 'CPU12 temperature' 的列名列表
cpu_usage_2 = [f'CPU{i} usage         ' for i in range(10, 13)]

# 合并两个列表
cpu_usage = cpu_usage_1 + cpu_usage_2

# 创建一个 4x3 的图像
fig, axs = plt.subplots(4, 3, figsize=(18, 24))
axs = axs.ravel()  # 将二维数组展平，方便遍历

# 遍历每个 CPU usage列，在对应的子图中绘制折线图
for i, cpu_col in enumerate(cpu_usage):
    row = i // 2  # 计算子图所在的行索引
    col = i % 2   # 计算子图所在的列索引
    
    # 绘制 df1 中对应 CPU usage的折线图
    axs[i].plot(df1_time_adjusted, df1[cpu_col], label='Local Running Data', color='blue')
    
    # 绘制 df2 中对应 CPU usage的折线图
    axs[i].plot(df2_time_adjusted, df2[cpu_col], label='Cloud Running Data', color='orange')
    
    # 设置子图标题和标签
    axs[i].set_title(cpu_col.strip())  # 去除列名中的额外空格并作为子图标题
    axs[i].set_xlabel('Time (seconds since start)')
    axs[i].set_ylabel('Usage')
    axs[i].legend()  # 显示图例

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['02', ' GPU temperature     ', 'GPU usage           ',
#        'FB usage            ', 'VID usage           ', 'BUS usage           ',
#        'Memory usage        ', 'Core clock          ', 'Memory clock        ',
#        'Power percent       ', 'Power               ', 'Temp limit          ',
#        'Power limit         ', 'Voltage limit       ', 'No load limit       ',
#        'CPU1 temperature    ', 'CPU2 temperature    ', 'CPU3 temperature    ',
#        'CPU4 temperature    ', 'CPU5 temperature    ', 'CPU6 temperature    ',
#        'CPU7 temperature    ', 'CPU8 temperature    ', 'CPU9 temperature    ',
#        'CPU10 temperature   ', 'CPU11 temperature   ', 'CPU12 temperature   ',
#        'CPU temperature     ', 'CPU1 usage          ', 'CPU2 usage          ',
#        'CPU3 usage          ', 'CPU4 usage          ', 'CPU5 usage          ',
#        'CPU6 usage          ', 'CPU7 usage          ', 'CPU8 usage          ',
#        'CPU9 usage          ', 'CPU10 usage         ', 'CPU11 usage         ',
#        'CPU12 usage         ', 'CPU usage           ', 'CPU1 clock          ',
#        'CPU2 clock          ', 'CPU3 clock          ', 'CPU4 clock          ',
#        'CPU5 clock          ', 'CPU6 clock          ', 'CPU7 clock          ',
#        'CPU8 clock          ', 'CPU9 clock          ', 'CPU10 clock         ',
#        'CPU11 clock         ', 'CPU12 clock         ', 'CPU clock           ',
#        'CPU power           ', 'RAM usage           ', 'Commit charge       ',
#        'Framerate           ', 'Frametime           ', 'Framerate Min       ',
#        'Framerate Avg       ', 'Framerate Max       '],
#       dtype='object')
# Index(['02', ' GPU temperature     ', 'GPU usage           ',
#        'FB usage            ', 'VID usage           ', 'BUS usage           ',
#        'Memory usage        ', 'Core clock          ', 'Memory clock        ',
#        'Power percent       ', 'Power               ', 'Temp limit          ',
#        'Power limit         ', 'Voltage limit       ', 'No load limit       ',
#        'CPU1 temperature    ', 'CPU2 temperature    ', 'CPU3 temperature    ',
#        'CPU4 temperature    ', 'CPU5 temperature    ', 'CPU6 temperature    ',
#        'CPU7 temperature    ', 'CPU8 temperature    ', 'CPU9 temperature    ',
#        'CPU10 temperature   ', 'CPU11 temperature   ', 'CPU12 temperature   ',
#        'CPU temperature     ', 'CPU1 usage          ', 'CPU2 usage          ',
#        'CPU3 usage          ', 'CPU4 usage          ', 'CPU5 usage          ',
#        'CPU6 usage          ', 'CPU7 usage          ', 'CPU8 usage          ',
#        'CPU9 usage          ', 'CPU10 usage         ', 'CPU11 usage         ',
#        'CPU12 usage         ', 'CPU usage           ', 'CPU1 clock          ',
#        'CPU2 clock          ', 'CPU3 clock          ', 'CPU4 clock          ',
#        'CPU5 clock          ', 'CPU6 clock          ', 'CPU7 clock          ',
#        'CPU8 clock          ', 'CPU9 clock          ', 'CPU10 clock         ',
#        'CPU11 clock         ', 'CPU12 clock         ', 'CPU clock           ',
#        'CPU power           ', 'RAM usage           ', 'Commit charge       ',
#        'Framerate           ', 'Frametime           ', 'Framerate Min       ',
#        'Framerate Avg       ', 'Framerate Max       '],
#       dtype='object')

# %%
# 选择需要的指标列
interest_columns = [' GPU temperature     ', 'GPU usage           ', 'Memory usage        ', 'RAM usage           ']

# 计算本地和云端数据每个指标的最大值、最小值和均值
df1_stats = data1[interest_columns].agg(['max', 'min', 'mean'])
df2_stats = data2[interest_columns].agg(['max', 'min', 'mean'])

# 创建一个包含4个子图的 1x4 布局的大图
fig, axs = plt.subplots(1, 4, figsize=(20, 6))

# 遍历每个感兴趣的指标列，在对应的子图中绘制柱状图对比
for i, col in enumerate(interest_columns):
    # 提取本地和云端数据中对应指标列的最大值、最小值和均值
    local_max = df1_stats.loc['max', col]
    local_min = df1_stats.loc['min', col]
    local_mean = df1_stats.loc['mean', col]
    
    cloud_max = df2_stats.loc['max', col]
    cloud_min = df2_stats.loc['min', col]
    cloud_mean = df2_stats.loc['mean', col]
    
    # 绘制柱状图
    bar_width = 0.35
    bar_positions_local = np.arange(3)
    bar_positions_cloud = np.arange(3) + bar_width
    
    axs[i].bar(bar_positions_local, [local_min, local_max, local_mean], width=bar_width, label='Local', color='blue')
    axs[i].bar(bar_positions_cloud, [cloud_min, cloud_max, cloud_mean], width=bar_width, label='Cloud', color='orange')
    
    # 设置子图标题和标签
    axs[i].set_title(col)  # 使用指标名称作为子图标题
    axs[i].set_xticks(bar_positions_local + bar_width / 2)
    axs[i].set_xticklabels(['Min', 'Max', 'Mean'])
    axs[i].set_ylabel('Value')
    axs[i].legend()  # 显示图例

# 调整子图间距和整体布局
plt.tight_layout()
plt.show()

# %%
# 生成 'CPU1 temperature' 到 'CPU9 temperature' 的列名列表
cpu_temperature_1 = [f'CPU{i} temperature    ' for i in range(1, 10)]

# 生成 'CPU10 temperature' 到 'CPU12 temperature' 的列名列表
cpu_temperature_2 = [f'CPU{i} temperature   ' for i in range(10, 13)]

# 合并两个列表
cpu_temperature = cpu_temperature_1 + cpu_temperature_2

# 创建一个包含12个子图的 4x3 布局的大图
fig, axs = plt.subplots(4, 3, figsize=(16, 24))
axs = axs.ravel()  # 将二维数组展平成一维，方便索引

# 遍历每个 CPU 温度列，在对应的子图中绘制柱状图
for i, cpu_col in enumerate(cpu_temperature):
    row = i // 2  # 计算子图所在的行索引
    col = i % 2   # 计算子图所在的列索引
    
    # 提取本地和云端数据中对应 CPU 温度列的数据
    local_data = df1[cpu_col]
    cloud_data = df2[cpu_col]
    
    # 计算本地和云端数据的最大值、最小值和均值
    local_max = local_data.max()
    local_min = local_data.min()
    local_mean = local_data.mean()
    
    cloud_max = cloud_data.max()
    cloud_min = cloud_data.min()
    cloud_mean = cloud_data.mean()
    
    # 绘制柱状图
    bar_width = 0.2
    bar_positions_local = np.arange(3) - bar_width / 2
    bar_positions_cloud = np.arange(3) + bar_width / 2
    
    axs[i].bar(bar_positions_local, [local_min, local_max, local_mean], width=bar_width, label='Local', color='blue')
    axs[i].bar(bar_positions_cloud, [cloud_min, cloud_max, cloud_mean], width=bar_width, label='Cloud', color='orange')
    
    # 设置子图标题和标签
    axs[i].set_title(cpu_col.strip())  # 去除列名中的额外空格并作为子图标题
    axs[i].set_xticks([0, 1, 2])
    axs[i].set_xticklabels(['Min', 'Max', 'Mean'])
    axs[i].set_ylabel('Temperature')
    axs[i].legend()  # 显示图例

# 调整子图间距和整体布局
plt.tight_layout()
plt.show()

# %%
# 生成 'CPU1 usage' 到 'CPU9 usage' 的列名列表
cpu_usage_1 = [f'CPU{i} usage          ' for i in range(1, 10)]

# 生成 'CPU10 temperature' 到 'CPU12 temperature' 的列名列表
cpu_usage_2 = [f'CPU{i} usage         ' for i in range(10, 13)]

# 合并两个列表
cpu_usage = cpu_usage_1 + cpu_usage_2

# 创建一个包含12个子图的 4x3 布局的大图
fig, axs = plt.subplots(4, 3, figsize=(16, 24))
axs = axs.ravel()  # 将二维数组展平成一维，方便索引

# 遍历每个 CPU usage列，在对应的子图中绘制柱状图
for i, cpu_col in enumerate(cpu_usage):
    row = i // 2  # 计算子图所在的行索引
    col = i % 2   # 计算子图所在的列索引
    
    # 提取本地和云端数据中对应 CPU usage列的数据
    local_data = df1[cpu_col]
    cloud_data = df2[cpu_col]
    
    # 计算本地和云端数据的最大值、最小值和均值
    local_max = local_data.max()
    local_min = local_data.min()
    local_mean = local_data.mean()
    
    cloud_max = cloud_data.max()
    cloud_min = cloud_data.min()
    cloud_mean = cloud_data.mean()
    
    # 绘制柱状图
    bar_width = 0.2
    bar_positions_local = np.arange(3) - bar_width / 2
    bar_positions_cloud = np.arange(3) + bar_width / 2
    
    axs[i].bar(bar_positions_local, [local_min, local_max, local_mean], width=bar_width, label='Local', color='blue')
    axs[i].bar(bar_positions_cloud, [cloud_min, cloud_max, cloud_mean], width=bar_width, label='Cloud', color='orange')
    
    # 设置子图标题和标签
    axs[i].set_title(cpu_col.strip())  # 去除列名中的额外空格并作为子图标题
    axs[i].set_xticks([0, 1, 2])
    axs[i].set_xticklabels(['Min', 'Max', 'Mean'])
    axs[i].set_ylabel('Usage')
    axs[i].legend()  # 显示图例

# 调整子图间距和整体布局
plt.tight_layout()
plt.show()
